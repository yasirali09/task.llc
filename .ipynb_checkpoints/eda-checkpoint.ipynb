# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Defining some utility functions

# %%
# Double y axis plot
def plot_line(df,col1,col2,lag1 = 0,lag2= 0):
    
    col1_val = df[col1].shift(lag1)
    col2_val = df[col2].shift(lag2)

    fig,ax = plt.subplots()
    
    ax.plot(df.index, col1_val, color="blue", marker=".")
    
    ax.set_xlabel("year",fontsize=14)
    
    ax.set_ylabel(col1,color="blue",fontsize=14)

    ax2=ax.twinx()
    # make a plot with different y-axis using second axis object
    ax2.plot(df.index, col2_val,color="red",marker=".")
    ax2.set_ylabel(col2,color="red",fontsize=14)
    plt.show()
    
    print(np.corrcoef(col1_val.dropna(),col2_val.dropna()))

# %%
# index
monthly_rng = pd.date_range("01-2001","1-2021", freq = "M")
monthly_rng
# Out:
# DatetimeIndex(['2001-01-31', '2001-02-28', '2001-03-31', '2001-04-30',
#                '2001-05-31', '2001-06-30', '2001-07-31', '2001-08-31',
#                '2001-09-30', '2001-10-31',
#                ...
#                '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30',
#                '2020-07-31', '2020-08-31', '2020-09-30', '2020-10-31',
#                '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', length=240, freq='M')

# %%
files = os.listdir("C:/Users/hp/Desktop/task/task.llc/cleaned_data")
len(files)
# Out:
# 29

# %%
df_dict = {}

for filename in files:
    tdf = pd.read_csv(os.path.join("cleaned_data",filename))
    df_dict.update({tdf.iloc[:,1].name : list(tdf.iloc[:,1])})
    
final_df = pd.DataFrame(df_dict,monthly_rng)

final_df.to_csv("C:/Users/hp/Desktop/task/task.llc/cleaned_data/final_df.csv")

# %%
final_df.rename(columns ={"0":"private_job_gains"},inplace=True)
df = final_df.copy()
df = df[:"2015"]
df["gdp_per_capita"] = df["GDP"]/df["population"]

# %%
df.corr()
# Out:
#                                      avg_expenditure_25_34  \
# avg_expenditure_25_34                             1.000000
# avg_expenditure_35_44                             0.983354
# avg_expenditure_45_54                             0.973711
# avg_expenditure_55_64                             0.984479
# CPI                                              -0.107668
# employees_construction                           -0.317665
# GDP                                               0.952762
# HCAI_GOVT                                        -0.790514
# HCAI_GSE                                         -0.559341
# HCAI_PP                                          -0.752091
# home-ownership-rate                              -0.522570
# houses-for-sale-to-sold                           0.469165
# industrial_production_cement                     -0.582519
# job_gains_private                                -0.591926
# MORTGAGE30US                                     -0.716270
# pvt_owned_house_under_const                      -0.458366
# nonresidential_const_val                          0.720185
# permits                                          -0.660915
# personal_saving_rate                              0.372560
# population                                        0.933571
# house_units_completed                            -0.650173
# producer_price_index_concrete_brick               0.939673
# residential_const_val                            -0.269678
# retail_sales_home_furnishing_stores               0.104997
# target                                            0.625049
# UNRATE                                            0.308999
# unrate_construction                               0.219969
# gdp_per_capita                                    0.961125
#
#                                      avg_expenditure_35_44  \
# avg_expenditure_25_34                             0.983354
# avg_expenditure_35_44                             1.000000
# avg_expenditure_45_54                             0.981350
# avg_expenditure_55_64                             0.973879
# CPI                                              -0.114017
# employees_construction                           -0.246568
# GDP                                               0.938442
# HCAI_GOVT                                        -0.758974
# HCAI_GSE                                         -0.517089
# HCAI_PP                                          -0.729627
# home-ownership-rate                              -0.508388
# houses-for-sale-to-sold                           0.504780
# industrial_production_cement                     -0.544088
# job_gains_private                                -0.542536
# MORTGAGE30US                                     -0.654057
# pvt_owned_house_under_const                      -0.390045
# nonresidential_const_val                          0.785094
# permits                                          -0.627182
# personal_saving_rate                              0.321769
# population                                        0.910183
# house_units_completed                            -0.600279
# producer_price_index_concrete_brick               0.921954
# residential_const_val                            -0.219257
# retail_sales_home_furnishing_stores               0.159092
# target                                            0.668978
# UNRATE                                            0.239996
# unrate_construction                               0.172775
# gdp_per_capita                                    0.947955
#
#                                      avg_expenditure_45_54  \
# avg_expenditure_25_34                             0.973711
# avg_expenditure_35_44                             0.981350
# avg_expenditure_45_54                             1.000000
# avg_expenditure_55_64                             0.975075
# CPI                                              -0.141566
# employees_construction                           -0.325187
# GDP                                               0.963686
# HCAI_GOVT                                        -0.814481
# HCAI_GSE                                         -0.593582
# HCAI_PP                                          -0.761067
# home-ownership-rate                              -0.609815
# houses-for-sale-to-sold                           0.405180
# industrial_production_cement                     -0.579428
# job_gains_private                                -0.573414
# MORTGAGE30US                                     -0.742264
# pvt_owned_house_under_const                      -0.422911
# nonresidential_const_val                          0.751907
# permits                                          -0.617112
# personal_saving_rate                              0.422436
# population                                        0.943799
# house_units_completed                            -0.632345
# producer_price_index_concrete_brick               0.930963
# residential_const_val                            -0.242935
# retail_sales_home_furnishing_stores               0.119018
# target                                            0.611540
# UNRATE                                            0.269972
# unrate_construction                               0.177581
# gdp_per_capita                                    0.967187
#
#                                      avg_expenditure_55_64       CPI  \
# avg_expenditure_25_34                             0.984479 -0.107668
# avg_expenditure_35_44                             0.973879 -0.114017
# avg_expenditure_45_54                             0.975075 -0.141566
# avg_expenditure_55_64                             1.000000 -0.115255
# CPI                                              -0.115255  1.000000
# employees_construction                           -0.349628  0.087648
# GDP                                               0.957653 -0.111063
# HCAI_GOVT                                        -0.818489  0.123025
# HCAI_GSE                                         -0.598444  0.145867
# HCAI_PP                                          -0.776111  0.119631
# home-ownership-rate                              -0.543647  0.164629
# houses-for-sale-to-sold                           0.459667 -0.062040
# industrial_production_cement                     -0.600693  0.118947
# job_gains_private                                -0.629341  0.047018
# MORTGAGE30US                                     -0.747343  0.106634
# pvt_owned_house_under_const                      -0.468607  0.092116
# nonresidential_const_val                          0.721489 -0.123432
# permits                                          -0.660310  0.139972
# personal_saving_rate                              0.391519 -0.164487
# population                                        0.945344 -0.124807
# house_units_completed                            -0.666056  0.085375
# producer_price_index_concrete_brick               0.949990 -0.122264
# residential_const_val                            -0.285953  0.098157
# retail_sales_home_furnishing_stores               0.073192  0.068915
# target                                            0.608795  0.011917
# UNRATE                                            0.339044 -0.059533
# unrate_construction                               0.235364  0.100415
# gdp_per_capita                                    0.963584 -0.102896
#
#                                      employees_construction       GDP  \
# avg_expenditure_25_34                             -0.317665  0.952762
# avg_expenditure_35_44                             -0.246568  0.938442
# avg_expenditure_45_54                             -0.325187  0.963686
# avg_expenditure_55_64                             -0.349628  0.957653
# CPI                                                0.087648 -0.111063
# employees_construction                             1.000000 -0.458099
# GDP                                               -0.458099  1.000000
# HCAI_GOVT                                          0.796232 -0.873797
# HCAI_GSE                                           0.910144 -0.663629
# HCAI_PP                                            0.727266 -0.820948
# home-ownership-rate                                0.642341 -0.713470
# houses-for-sale-to-sold                            0.039596  0.271414
# industrial_production_cement                       0.898777 -0.638888
# job_gains_private                                  0.733403 -0.647996
# MORTGAGE30US                                       0.751698 -0.832291
# pvt_owned_house_under_const                        0.942423 -0.530390
# nonresidential_const_val                           0.114651  0.641364
# permits                                            0.736305 -0.641393
# personal_saving_rate                              -0.767610  0.513176
# population                                        -0.579379  0.988058
# house_units_completed                              0.864734 -0.711062
# producer_price_index_concrete_brick               -0.570863  0.950969
# residential_const_val                              0.850321 -0.316552
# retail_sales_home_furnishing_stores                0.796551  0.048127
# target                                             0.441405  0.515745
# UNRATE                                            -0.873424  0.331420
# unrate_construction                               -0.697267  0.196466
# gdp_per_capita                                    -0.414852  0.998465
#
#                                      HCAI_GOVT  HCAI_GSE   HCAI_PP  ...  \
# avg_expenditure_25_34                -0.790514 -0.559341 -0.752091  ...
# avg_expenditure_35_44                -0.758974 -0.517089 -0.729627  ...
# avg_expenditure_45_54                -0.814481 -0.593582 -0.761067  ...
# avg_expenditure_55_64                -0.818489 -0.598444 -0.776111  ...
# CPI                                   0.123025  0.145867  0.119631  ...
# employees_construction                0.796232  0.910144  0.727266  ...
# GDP                                  -0.873797 -0.663629 -0.820948  ...
# HCAI_GOVT                             1.000000  0.932369  0.922474  ...
# HCAI_GSE                              0.932369  1.000000  0.857535  ...
# HCAI_PP                               0.922474  0.857535  1.000000  ...
# home-ownership-rate                   0.771419  0.726700  0.767425  ...
# houses-for-sale-to-sold              -0.246857 -0.164190 -0.348628  ...
# industrial_production_cement          0.900003  0.928273  0.860492  ...
# job_gains_private                     0.778144  0.726921  0.646058  ...
# MORTGAGE30US                          0.898562  0.822291  0.785734  ...
# pvt_owned_house_under_const           0.825437  0.899011  0.838899  ...
# nonresidential_const_val             -0.420078 -0.216452 -0.557894  ...
# permits                               0.829396  0.823093  0.886756  ...
# personal_saving_rate                 -0.703926 -0.763114 -0.690076  ...
# population                           -0.933326 -0.760101 -0.869804  ...
# house_units_completed                 0.917325  0.918802  0.943241  ...
# producer_price_index_concrete_brick  -0.925116 -0.760676 -0.908763  ...
# residential_const_val                 0.666152  0.801145  0.761120  ...
# retail_sales_home_furnishing_stores   0.415025  0.663222  0.434242  ...
# target                               -0.114472  0.200154 -0.022752  ...
# UNRATE                               -0.683054 -0.795128 -0.580771  ...
# unrate_construction                  -0.520159 -0.625052 -0.443510  ...
# gdp_per_capita                       -0.849903 -0.627309 -0.797713  ...
#
#                                      personal_saving_rate  population  \
# avg_expenditure_25_34                            0.372560    0.933571
# avg_expenditure_35_44                            0.321769    0.910183
# avg_expenditure_45_54                            0.422436    0.943799
# avg_expenditure_55_64                            0.391519    0.945344
# CPI                                             -0.164487   -0.124807
# employees_construction                          -0.767610   -0.579379
# GDP                                              0.513176    0.988058
# HCAI_GOVT                                       -0.703926   -0.933326
# HCAI_GSE                                        -0.763114   -0.760101
# HCAI_PP                                         -0.690076   -0.869804
# home-ownership-rate                             -0.773561   -0.735983
# houses-for-sale-to-sold                         -0.129012    0.279472
# industrial_production_cement                    -0.694100   -0.741714
# job_gains_private                               -0.503021   -0.723660
# MORTGAGE30US                                    -0.731912   -0.879718
# pvt_owned_house_under_const                     -0.717252   -0.641463
# nonresidential_const_val                         0.120881    0.578643
# permits                                         -0.565740   -0.723108
# personal_saving_rate                             1.000000    0.585162
# population                                       0.585162    1.000000
# house_units_completed                           -0.708398   -0.795361
# producer_price_index_concrete_brick              0.538677    0.971864
# residential_const_val                           -0.646885   -0.435204
# retail_sales_home_furnishing_stores             -0.499796   -0.096207
# target                                          -0.317214    0.411704
# UNRATE                                           0.521797    0.465809
# unrate_construction                              0.357137    0.316491
# gdp_per_capita                                   0.475179    0.979939
#
#                                      house_units_completed  \
# avg_expenditure_25_34                            -0.650173
# avg_expenditure_35_44                            -0.600279
# avg_expenditure_45_54                            -0.632345
# avg_expenditure_55_64                            -0.666056
# CPI                                               0.085375
# employees_construction                            0.864734
# GDP                                              -0.711062
# HCAI_GOVT                                         0.917325
# HCAI_GSE                                          0.918802
# HCAI_PP                                           0.943241
# home-ownership-rate                               0.671447
# houses-for-sale-to-sold                          -0.333334
# industrial_production_cement                      0.951531
# job_gains_private                                 0.739511
# MORTGAGE30US                                      0.781439
# pvt_owned_house_under_const                       0.952766
# nonresidential_const_val                         -0.336439
# permits                                           0.939369
# personal_saving_rate                             -0.708398
# population                                       -0.795361
# house_units_completed                             1.000000
# producer_price_index_concrete_brick              -0.843282
# residential_const_val                             0.874473
# retail_sales_home_furnishing_stores               0.634860
# target                                            0.138613
# UNRATE                                           -0.781088
# unrate_construction                              -0.648723
# gdp_per_capita                                   -0.682165
#
#                                      producer_price_index_concrete_brick  \
# avg_expenditure_25_34                                           0.939673
# avg_expenditure_35_44                                           0.921954
# avg_expenditure_45_54                                           0.930963
# avg_expenditure_55_64                                           0.949990
# CPI                                                            -0.122264
# employees_construction                                         -0.570863
# GDP                                                             0.950969
# HCAI_GOVT                                                      -0.925116
# HCAI_GSE                                                       -0.760676
# HCAI_PP                                                        -0.908763
# home-ownership-rate                                            -0.645724
# houses-for-sale-to-sold                                         0.452718
# industrial_production_cement                                   -0.787254
# job_gains_private                                              -0.721907
# MORTGAGE30US                                                   -0.809037
# pvt_owned_house_under_const                                    -0.690493
# nonresidential_const_val                                        0.645007
# permits                                                        -0.825847
# personal_saving_rate                                            0.538677
# population                                                      0.971864
# house_units_completed                                          -0.843282
# producer_price_index_concrete_brick                             1.000000
# residential_const_val                                          -0.528578
# retail_sales_home_furnishing_stores                            -0.181363
# target                                                          0.385425
# UNRATE                                                          0.525552
# unrate_construction                                             0.403233
# gdp_per_capita                                                  0.944122
#
#                                      residential_const_val  \
# avg_expenditure_25_34                            -0.269678
# avg_expenditure_35_44                            -0.219257
# avg_expenditure_45_54                            -0.242935
# avg_expenditure_55_64                            -0.285953
# CPI                                               0.098157
# employees_construction                            0.850321
# GDP                                              -0.316552
# HCAI_GOVT                                         0.666152
# HCAI_GSE                                          0.801145
# HCAI_PP                                           0.761120
# home-ownership-rate                               0.477084
# houses-for-sale-to-sold                          -0.292336
# industrial_production_cement                      0.869379
# job_gains_private                                 0.533985
# MORTGAGE30US                                      0.501032
# pvt_owned_house_under_const                       0.940477
# nonresidential_const_val                         -0.102248
# permits                                           0.872419
# personal_saving_rate                             -0.646885
# population                                       -0.435204
# house_units_completed                             0.874473
# producer_price_index_concrete_brick              -0.528578
# residential_const_val                             1.000000
# retail_sales_home_furnishing_stores               0.882013
# target                                            0.530377
# UNRATE                                           -0.804483
# unrate_construction                              -0.710614
# gdp_per_capita                                   -0.277452
#
#                                      retail_sales_home_furnishing_stores  \
# avg_expenditure_25_34                                           0.104997
# avg_expenditure_35_44                                           0.159092
# avg_expenditure_45_54                                           0.119018
# avg_expenditure_55_64                                           0.073192
# CPI                                                             0.068915
# employees_construction                                          0.796551
# GDP                                                             0.048127
# HCAI_GOVT                                                       0.415025
# HCAI_GSE                                                        0.663222
# HCAI_PP                                                         0.434242
# home-ownership-rate                                             0.224654
# houses-for-sale-to-sold                                        -0.116558
# industrial_production_cement                                    0.704057
# job_gains_private                                               0.409822
# MORTGAGE30US                                                    0.278028
# pvt_owned_house_under_const                                     0.789799
# nonresidential_const_val                                        0.273857
# permits                                                         0.625967
# personal_saving_rate                                           -0.499796
# population                                                     -0.096207
# house_units_completed                                           0.634860
# producer_price_index_concrete_brick                            -0.181363
# residential_const_val                                           0.882013
# retail_sales_home_furnishing_stores                             1.000000
# target                                                          0.747604
# UNRATE                                                         -0.812063
# unrate_construction                                            -0.736876
# gdp_per_capita                                                  0.091640
#
#                                        target    UNRATE  unrate_construction  \
# avg_expenditure_25_34                0.625049  0.308999             0.219969
# avg_expenditure_35_44                0.668978  0.239996             0.172775
# avg_expenditure_45_54                0.611540  0.269972             0.177581
# avg_expenditure_55_64                0.608795  0.339044             0.235364
# CPI                                  0.011917 -0.059533             0.100415
# employees_construction               0.441405 -0.873424            -0.697267
# GDP                                  0.515745  0.331420             0.196466
# HCAI_GOVT                           -0.114472 -0.683054            -0.520159
# HCAI_GSE                             0.200154 -0.795128            -0.625052
# HCAI_PP                             -0.022752 -0.580771            -0.443510
# home-ownership-rate                  0.081625 -0.264958            -0.093744
# houses-for-sale-to-sold              0.359470  0.268890             0.369234
# industrial_production_cement         0.173949 -0.860516            -0.726654
# job_gains_private                   -0.126550 -0.785716            -0.641542
# MORTGAGE30US                        -0.116604 -0.575993            -0.389523
# pvt_owned_house_under_const          0.354109 -0.873570            -0.728905
# nonresidential_const_val             0.555403 -0.149428            -0.130949
# permits                              0.066124 -0.769557            -0.687234
# personal_saving_rate                -0.317214  0.521797             0.357137
# population                           0.411704  0.465809             0.316491
# house_units_completed                0.138613 -0.781088            -0.648723
# producer_price_index_concrete_brick  0.385425  0.525552             0.403233
# residential_const_val                0.530377 -0.804483            -0.710614
# retail_sales_home_furnishing_stores  0.747604 -0.812063            -0.736876
# target                               1.000000 -0.314352            -0.278919
# UNRATE                              -0.314352  1.000000             0.870846
# unrate_construction                 -0.278919  0.870846             1.000000
# gdp_per_capita                       0.558284  0.300556             0.172746
#
#                                      gdp_per_capita
# avg_expenditure_25_34                      0.961125
# avg_expenditure_35_44                      0.947955
# avg_expenditure_45_54                      0.967187
# avg_expenditure_55_64                      0.963584
# CPI                                       -0.102896
# employees_construction                    -0.414852
# GDP                                        0.998465
# HCAI_GOVT                                 -0.849903
# HCAI_GSE                                  -0.627309
# HCAI_PP                                   -0.797713
# home-ownership-rate                       -0.680890
# houses-for-sale-to-sold                    0.289106
# industrial_production_cement              -0.605790
# job_gains_private                         -0.633337
# MORTGAGE30US                              -0.809861
# pvt_owned_house_under_const               -0.494445
# nonresidential_const_val                   0.655498
# permits                                   -0.619989
# personal_saving_rate                       0.475179
# population                                 0.979939
# house_units_completed                     -0.682165
# producer_price_index_concrete_brick        0.944122
# residential_const_val                     -0.277452
# retail_sales_home_furnishing_stores        0.091640
# target                                     0.558284
# UNRATE                                     0.300556
# unrate_construction                        0.172746
# gdp_per_capita                             1.000000
#
# [28 rows x 28 columns]

# %% [markdown]
# ## Demographic
# - Population

# %% [markdown]
# ## Income-age distribution
# - average expenditure 25-34
# - average expenditure 35-44
# - average expenditure 45-54
# - average expenditure 55-64
#
# ## Mortagages
# - HCAI_GOVT
# - HCAI_GSE
# - HCAI_PP
# - MORTGAGE30US
# ## Health of the economy
# - GDP
# - CPI
# - private_job_gains
# - personal_saving_rate
# - UNRATE - Unemployment rate
# - unrate_construction - Unemployment rate in construction industry
# ## Construction Industry
# - employees_construction
# - industrial_production_cement
# - pvt_owned_house_under_const
# - residential_const_val
# - producer_price_index_concrete_brick
# ## Housing industry
# - houses-for-sale-to-sold - Number of houses for sale vs number of houses got sold
# - home-ownership-rate
# - house_units_completed - Number of new house units completed in a given month
# - retail_sales_home_furnishing_stores - Sales of home furnishing stores
# ## Infrastructure and permits
# - nonresidential_const_val
# - permits

# %% [markdown]
# ## DEMOGRAPHICS FACTORS

# %%
demodf = df.copy()
demodf = demodf[["population","avg_expenditure_25_34","avg_expenditure_35_44","avg_expenditure_55_64","avg_expenditure_45_54","target"]]
demodf
# Out:
#             population  avg_expenditure_25_34  avg_expenditure_35_44  \
# 2001-01-31   284169.00                38987.0                45296.0
# 2001-02-28   284392.00                39029.0                45443.0
# 2001-03-31   284615.00                39071.0                45590.0
# 2001-04-30   284838.00                39113.0                45737.0
# 2001-05-31   285086.67                39155.0                45884.0
# ...                ...                    ...                    ...
# 2015-08-31   321413.67                51227.0                64392.0
# 2015-09-30   321622.34                51437.0                64627.0
# 2015-10-31   321831.00                51647.0                64862.0
# 2015-11-30   322005.33                51857.0                65097.0
# 2015-12-31   322179.66                52067.0                65332.0
#
#             avg_expenditure_55_64  avg_expenditure_45_54   target
# 2001-01-31                39517.0                46308.0  109.845
# 2001-02-28                39694.0                46456.0  110.499
# 2001-03-31                39871.0                46604.0  111.107
# 2001-04-30                40048.0                46752.0  111.650
# 2001-05-31                40225.0                46900.0  112.162
# ...                           ...                    ...      ...
# 2015-08-31                57947.0                68387.0  172.954
# 2015-09-30                58157.0                68729.0  173.848
# 2015-10-31                58367.0                69071.0  174.811
# 2015-11-30                58577.0                69413.0  175.755
# 2015-12-31                58787.0                69755.0  176.556
#
# [180 rows x 6 columns]

# %%
figure, axis = plt.subplots(2, 3, figsize=(25, 10))

sns.histplot(demodf['population'], ax=axis[0, 0])
axis[0, 0].set_title("population")

sns.histplot(demodf['avg_expenditure_25_34'], ax=axis[0, 1])
axis[0, 1].set_title("avg_expenditure_25_34")

sns.histplot(demodf['avg_expenditure_35_44'], ax=axis[0, 2])
axis[0, 2].set_title("avg_expenditure_35_44")

sns.histplot(demodf['avg_expenditure_45_54'], ax=axis[1, 0])
axis[1, 0].set_title("avg_expenditure_45_54")

sns.histplot(demodf['avg_expenditure_55_64'], ax=axis[1, 1])
axis[1, 1].set_title("avg_expenditure_55_64")

sns.histplot(demodf['target'], ax=axis[1, 2])
axis[1, 2].set_title("target")

plt.show()

# %%
figure, axis = plt.subplots(2, 3, figsize=(25,10))

sns.boxplot(demodf['population'], ax=axis[0, 0])
axis[0, 0].set_title("population")

sns.boxplot(demodf['avg_expenditure_25_34'], ax=axis[0, 1])
axis[0, 1].set_title("avg_expenditure_25_34")

sns.boxplot(demodf['avg_expenditure_35_44'], ax=axis[0, 2])
axis[0, 2].set_title("avg_expenditure_35_44")



sns.boxplot(demodf['avg_expenditure_45_54'], ax=axis[1, 0])
axis[1, 0].set_title("avg_expenditure_45_54")

sns.boxplot(demodf['avg_expenditure_55_64'], ax=axis[1, 1])
axis[1, 1].set_title("avg_expenditure_55_64")

sns.boxplot(demodf['target'], ax=axis[1, 2])
axis[1, 2].set_title("target")
# Out:
# Text(0.5, 1.0, 'target')

# %%
plot_line(demodf,"target","population")
# Out:
# [[1.        0.4117042]
#  [0.4117042 1.       ]]

# %%
plot_line(demodf,"target","avg_expenditure_25_34")
# Out:
# [[1.         0.62504918]
#  [0.62504918 1.        ]]

# %%
plot_line(demodf,"target","avg_expenditure_45_54")
# Out:
# [[1.         0.61154038]
#  [0.61154038 1.        ]]

# %%
plot_line(demodf,"target","avg_expenditure_35_44")
# Out:
# [[1.         0.66897841]
#  [0.66897841 1.        ]]

# %%
plot_line(demodf,"target","avg_expenditure_55_64")
# Out:
# [[1.         0.60879469]
#  [0.60879469 1.        ]]

# %%
sns.heatmap(demodf.corr())
# Out:
# <Axes: >

# %% [markdown]
# - There exists a very high collinearity between target and four independent variables, but the four independent variables into consideration are also highly correlated

# %% [markdown]
# ## With lag of 12 months

# %%
demodf["avg_expenditure_55_64_lag12"] = demodf.avg_expenditure_55_64.shift(12).dropna()
demodf["avg_expenditure_35_44_lag12"] = demodf.avg_expenditure_35_44.shift(12).dropna()
demodf["avg_expenditure_25_34_lag12"] = demodf.avg_expenditure_25_34.shift(12).dropna()
demodf["population_lag"] = demodf.population.shift(12).dropna()

# %%
sns.heatmap(demodf.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Calculating rate of change of average expenditure accross age groups

# %%
demodf["avg_expenditure_55_64_rate"] = np.log(demodf.avg_expenditure_55_64/demodf.avg_expenditure_55_64.shift(12))
demodf["avg_expenditure_35_44_rate"] = np.log(demodf.avg_expenditure_35_44/demodf.avg_expenditure_35_44.shift(12))
demodf["avg_expenditure_25_34_rate"] = np.log(demodf.avg_expenditure_25_34/demodf.avg_expenditure_25_34.shift(12))
demodf["avg_expenditure_45_54_rate"] = np.log(demodf.avg_expenditure_45_54/demodf.avg_expenditure_45_54.shift(12))

# %%
(demodf.corr())
# Out:
#                              population  avg_expenditure_25_34  \
# population                     1.000000               0.933571
# avg_expenditure_25_34          0.933571               1.000000
# avg_expenditure_35_44          0.910183               0.983354
# avg_expenditure_55_64          0.945344               0.984479
# avg_expenditure_45_54          0.943799               0.973711
# target                         0.411704               0.625049
# avg_expenditure_55_64_lag12    0.941846               0.938263
# avg_expenditure_35_44_lag12    0.897390               0.940010
# avg_expenditure_25_34_lag12    0.927154               0.949772
# population_lag                 0.999873               0.911341
# avg_expenditure_55_64_rate    -0.428733              -0.283387
# avg_expenditure_35_44_rate    -0.137960               0.003142
# avg_expenditure_25_34_rate    -0.238325              -0.059832
# avg_expenditure_45_54_rate    -0.048144               0.068392
#
#                              avg_expenditure_35_44  avg_expenditure_55_64  \
# population                                0.910183               0.945344
# avg_expenditure_25_34                     0.983354               0.984479
# avg_expenditure_35_44                     1.000000               0.973879
# avg_expenditure_55_64                     0.973879               1.000000
# avg_expenditure_45_54                     0.981350               0.975075
# target                                    0.668978               0.608795
# avg_expenditure_55_64_lag12               0.931590               0.959612
# avg_expenditure_35_44_lag12               0.940682               0.943974
# avg_expenditure_25_34_lag12               0.935488               0.966569
# population_lag                            0.879996               0.930815
# avg_expenditure_55_64_rate               -0.294672              -0.300806
# avg_expenditure_35_44_rate                0.059522              -0.035084
# avg_expenditure_25_34_rate               -0.077720              -0.162794
# avg_expenditure_45_54_rate                0.086981               0.049074
#
#                              avg_expenditure_45_54    target  \
# population                                0.943799  0.411704
# avg_expenditure_25_34                     0.973711  0.625049
# avg_expenditure_35_44                     0.981350  0.668978
# avg_expenditure_55_64                     0.975075  0.608795
# avg_expenditure_45_54                     1.000000  0.611540
# target                                    0.611540  1.000000
# avg_expenditure_55_64_lag12               0.941884  0.366832
# avg_expenditure_35_44_lag12               0.924538  0.349961
# avg_expenditure_25_34_lag12               0.922306  0.346783
# population_lag                            0.924631  0.226360
# avg_expenditure_55_64_rate               -0.323823  0.095960
# avg_expenditure_35_44_rate                0.034370  0.565489
# avg_expenditure_25_34_rate               -0.074447  0.402502
# avg_expenditure_45_54_rate                0.160660  0.378036
#
#                              avg_expenditure_55_64_lag12  \
# population                                      0.941846
# avg_expenditure_25_34                           0.938263
# avg_expenditure_35_44                           0.931590
# avg_expenditure_55_64                           0.959612
# avg_expenditure_45_54                           0.941884
# target                                          0.366832
# avg_expenditure_55_64_lag12                     1.000000
# avg_expenditure_35_44_lag12                     0.973694
# avg_expenditure_25_34_lag12                     0.982294
# population_lag                                  0.937254
# avg_expenditure_55_64_rate                     -0.556325
# avg_expenditure_35_44_rate                     -0.228478
# avg_expenditure_25_34_rate                     -0.345392
# avg_expenditure_45_54_rate                     -0.137818
#
#                              avg_expenditure_35_44_lag12  \
# population                                      0.897390
# avg_expenditure_25_34                           0.940010
# avg_expenditure_35_44                           0.940682
# avg_expenditure_55_64                           0.943974
# avg_expenditure_45_54                           0.924538
# target                                          0.349961
# avg_expenditure_55_64_lag12                     0.973694
# avg_expenditure_35_44_lag12                     1.000000
# avg_expenditure_25_34_lag12                     0.982953
# population_lag                                  0.891305
# avg_expenditure_55_64_rate                     -0.515692
# avg_expenditure_35_44_rate                     -0.281766
# avg_expenditure_25_34_rate                     -0.348532
# avg_expenditure_45_54_rate                     -0.173858
#
#                              avg_expenditure_25_34_lag12  population_lag  \
# population                                      0.927154        0.999873
# avg_expenditure_25_34                           0.949772        0.911341
# avg_expenditure_35_44                           0.935488        0.879996
# avg_expenditure_55_64                           0.966569        0.930815
# avg_expenditure_45_54                           0.922306        0.924631
# target                                          0.346783        0.226360
# avg_expenditure_55_64_lag12                     0.982294        0.937254
# avg_expenditure_35_44_lag12                     0.982953        0.891305
# avg_expenditure_25_34_lag12                     1.000000        0.922247
# population_lag                                  0.922247        1.000000
# avg_expenditure_55_64_rate                     -0.475575       -0.427000
# avg_expenditure_35_44_rate                     -0.242596       -0.139699
# avg_expenditure_25_34_rate                     -0.368826       -0.238055
# avg_expenditure_45_54_rate                     -0.178342       -0.048488
#
#                              avg_expenditure_55_64_rate  \
# population                                    -0.428733
# avg_expenditure_25_34                         -0.283387
# avg_expenditure_35_44                         -0.294672
# avg_expenditure_55_64                         -0.300806
# avg_expenditure_45_54                         -0.323823
# target                                         0.095960
# avg_expenditure_55_64_lag12                   -0.556325
# avg_expenditure_35_44_lag12                   -0.515692
# avg_expenditure_25_34_lag12                   -0.475575
# population_lag                                -0.427000
# avg_expenditure_55_64_rate                     1.000000
# avg_expenditure_35_44_rate                     0.683753
# avg_expenditure_25_34_rate                     0.678245
# avg_expenditure_45_54_rate                     0.604836
#
#                              avg_expenditure_35_44_rate  \
# population                                    -0.137960
# avg_expenditure_25_34                          0.003142
# avg_expenditure_35_44                          0.059522
# avg_expenditure_55_64                         -0.035084
# avg_expenditure_45_54                          0.034370
# target                                         0.565489
# avg_expenditure_55_64_lag12                   -0.228478
# avg_expenditure_35_44_lag12                   -0.281766
# avg_expenditure_25_34_lag12                   -0.242596
# population_lag                                -0.139699
# avg_expenditure_55_64_rate                     0.683753
# avg_expenditure_35_44_rate                     1.000000
# avg_expenditure_25_34_rate                     0.798963
# avg_expenditure_45_54_rate                     0.735182
#
#                              avg_expenditure_25_34_rate  \
# population                                    -0.238325
# avg_expenditure_25_34                         -0.059832
# avg_expenditure_35_44                         -0.077720
# avg_expenditure_55_64                         -0.162794
# avg_expenditure_45_54                         -0.074447
# target                                         0.402502
# avg_expenditure_55_64_lag12                   -0.345392
# avg_expenditure_35_44_lag12                   -0.348532
# avg_expenditure_25_34_lag12                   -0.368826
# population_lag                                -0.238055
# avg_expenditure_55_64_rate                     0.678245
# avg_expenditure_35_44_rate                     0.798963
# avg_expenditure_25_34_rate                     1.000000
# avg_expenditure_45_54_rate                     0.766885
#
#                              avg_expenditure_45_54_rate
# population                                    -0.048144
# avg_expenditure_25_34                          0.068392
# avg_expenditure_35_44                          0.086981
# avg_expenditure_55_64                          0.049074
# avg_expenditure_45_54                          0.160660
# target                                         0.378036
# avg_expenditure_55_64_lag12                   -0.137818
# avg_expenditure_35_44_lag12                   -0.173858
# avg_expenditure_25_34_lag12                   -0.178342
# population_lag                                -0.048488
# avg_expenditure_55_64_rate                     0.604836
# avg_expenditure_35_44_rate                     0.735182
# avg_expenditure_25_34_rate                     0.766885
# avg_expenditure_45_54_rate                     1.000000

# %% [markdown]
# ### Since median age of homebuyers(all) is 47 years in USA, we'll combine average expenditure 35-44 age group with average expenditure 45-54 age group
# - Source [https://www.financialsamurai.com/the-median-homebuyer-age-is-now-so-old/]

# %%
df["avg_expenditure_35_54"] = df["avg_expenditure_35_44"] +df["avg_expenditure_45_54"]

# %% [markdown]
# ## Mortgages
# - HCAI_GOVT
# - HCAI_GSE
# - HCAI_PP
# - MORTGAGE30US

# %%
mordf = df.copy()
mordf = mordf[["target","HCAI_GOVT","HCAI_GSE","HCAI_PP","MORTGAGE30US"]]
mordf
# Out:
#              target  HCAI_GOVT  HCAI_GSE  HCAI_PP  MORTGAGE30US
# 2001-01-31  109.845     22.218     5.836   16.253        7.0325
# 2001-02-28  110.499     22.108     5.776   16.053        7.0500
# 2001-03-31  111.107     21.998     5.716   15.853        6.9520
# 2001-04-30  111.650     21.887     5.647   15.664        7.0775
# 2001-05-31  112.162     22.037     5.617   15.514        7.1450
# ...             ...        ...       ...      ...           ...
# 2015-08-31  172.954      9.735     2.221    2.358        3.9050
# 2015-09-30  173.848      9.775     2.231    2.388        3.8900
# 2015-10-31  174.811      9.805     2.230    2.432        3.7960
# 2015-11-30  175.755      9.945     2.260    2.492        3.9425
# 2015-12-31  176.556     10.085     2.290    2.552        3.9640
#
# [180 rows x 5 columns]

# %%
# Distribution plots 
figure, axis = plt.subplots(2, 2, figsize=(25,10))

sns.histplot(mordf['HCAI_GOVT'], ax=axis[0, 0])
axis[0, 0].set_title("HCAI_GOVT")

sns.histplot(mordf['HCAI_GSE'], ax=axis[0, 1])
axis[0, 1].set_title("HCAI_GSE")




sns.histplot(mordf['HCAI_PP'], ax=axis[1, 0])
axis[1, 0].set_title("HCAI_PP")

sns.histplot(mordf['MORTGAGE30US'], ax=axis[1, 1])
axis[1, 1].set_title("MORTGAGE30US")
# Out:
# Text(0.5, 1.0, 'MORTGAGE30US')

# %%
#Box plots
figure, axis = plt.subplots(2, 2, figsize=(25,10))

sns.boxplot(mordf['HCAI_GOVT'], ax=axis[0, 0])
axis[0, 0].set_title("HCAI_GOVT")

sns.boxplot(mordf['HCAI_GSE'], ax=axis[0, 1])
axis[0, 1].set_title("HCAI_GSE")




sns.boxplot(mordf['HCAI_PP'], ax=axis[1, 0])
axis[1, 0].set_title("HCAI_PP")

sns.boxplot(mordf['MORTGAGE30US'], ax=axis[1, 1])
axis[1, 1].set_title("MORTGAGE30US")
# Out:
# Text(0.5, 1.0, 'MORTGAGE30US')

# %% [markdown]
# ## There exists a high correlation between target and HCAI index with lag of 96( 8 years), but since we have limited data, we cannot use lag of 96

# %%
plot_line(mordf,"target","HCAI_GOVT")
# Out:
# [[ 1.         -0.11447179]
#  [-0.11447179  1.        ]]

# %%
plot_line(mordf,"target","HCAI_GSE")
# Out:
# [[1.         0.20015417]
#  [0.20015417 1.        ]]

# %%
plot_line(mordf,"target","HCAI_PP")
# Out:
# [[ 1.         -0.02275183]
#  [-0.02275183  1.        ]]

# %%
plot_line(mordf,"target","MORTGAGE30US")
# Out:
# [[ 1.         -0.11660445]
#  [-0.11660445  1.        ]]

# %%
sns.heatmap(mordf.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Health of the economy
# - GDP
# - CPI
# - private_job_gains
# - personal_saving_rate
# - UNRATE - Unemployment rate
# - unrate_construction - Unemployment rate in construction industry

# %%
ecodf = df.copy()
ecodf = ecodf[["target","GDP","CPI","job_gains_private","UNRATE","unrate_construction"]]
ecodf
# Out:
#              target        GDP       CPI  job_gains_private  UNRATE  \
# 2001-01-31  109.845  10470.231  0.632184            3001.33     4.2
# 2001-02-28  110.499  10513.151  0.399772            3001.33     4.2
# 2001-03-31  111.107  10556.071  0.227531            3001.33     4.3
# 2001-04-30  111.650  10599.000  0.397276            2813.00     4.4
# 2001-05-31  112.162  10598.670  0.452233            2813.00     4.3
# ...             ...        ...       ...                ...     ...
# 2015-08-31  172.954  18315.330 -0.141628            2415.67     5.1
# 2015-09-30  173.848  18323.700 -0.155676            2415.67     5.0
# 2015-10-31  174.811  18332.079 -0.044968            2539.00     5.0
# 2015-11-30  175.755  18363.159 -0.211068            2539.00     5.1
# 2015-12-31  176.556  18394.239 -0.341710            2539.00     5.0
#
#             unrate_construction
# 2001-01-31                  9.8
# 2001-02-28                  9.9
# 2001-03-31                  8.4
# 2001-04-30                  7.1
# 2001-05-31                  5.6
# ...                         ...
# 2015-08-31                  6.1
# 2015-09-30                  5.5
# 2015-10-31                  6.2
# 2015-11-30                  6.2
# 2015-12-31                  7.5
#
# [180 rows x 6 columns]

# %%
figure, axis = plt.subplots(2, 3, figsize=(25,10))

sns.histplot(ecodf['GDP'], ax=axis[0, 0])
axis[0, 0].set_title("GDP")

sns.histplot(ecodf['CPI'], ax=axis[0, 1])
axis[0, 1].set_title("CPI")


sns.histplot(ecodf['job_gains_private'], ax=axis[0, 2])
axis[1, 0].set_title("job_gains_private")


sns.histplot(ecodf['UNRATE'], ax=axis[1, 0])
axis[1, 0].set_title("UNRATE")

sns.histplot(ecodf['unrate_construction'], ax=axis[1, 1])
axis[1, 1].set_title("unrate_construction")
# Out:
# Text(0.5, 1.0, 'unrate_construction')

# %%
figure, axis = plt.subplots(2, 3, figsize=(25,10))

sns.boxplot(ecodf['GDP'], ax=axis[0, 0])
axis[0, 0].set_title("GDP")

sns.boxplot(ecodf['CPI'], ax=axis[0, 1])
axis[0, 1].set_title("CPI")


sns.boxplot(ecodf['job_gains_private'], ax=axis[0, 2])
axis[1, 0].set_title("job_gains_private")


sns.boxplot(ecodf['UNRATE'], ax=axis[1, 0])
axis[1, 0].set_title("UNRATE")

sns.boxplot(ecodf['unrate_construction'], ax=axis[1, 1])
axis[1, 1].set_title("unrate_construction")
# Out:
# Text(0.5, 1.0, 'unrate_construction')

# %% [markdown]
# ## Using log tranformation to handle outliers

# %%
ecodf['unrate_construction'] = np.log(ecodf['unrate_construction'])

# %% [markdown]
# ### Private job gains is number of job gains in the given month, hence we can add a cum sum of the series as a feature

# %%
ecodf["private_job_gains_cum"] = ecodf["job_gains_private"].cumsum()

# %%
np.corrcoef(ecodf["target"],ecodf["private_job_gains_cum"]/ecodf["UNRATE"])
# Out:
# array([[1.        , 0.67467396],
#        [0.67467396, 1.        ]])

# %%
ecodf["private_job_gains_cum_per_unrate"] = ecodf["private_job_gains_cum"]/ecodf["UNRATE"]

# %%
sns.heatmap(ecodf.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - We have calculate GDP per capita, hence we can drop GDP
# - We have also calculated cumulative private job gains per unit unemployment rate
# - Neither CPI, nor CPI rate is linearly correlated with data
# - Unemployment rate, private job gains, unemployment rate construction are also highly correlated with each other

# %%
sns.boxplot(ecodf['private_job_gains_cum'])
# Out:
# <Axes: >

# %% [markdown]
# ## Construction Industry
# - employees_construction
# - industrial_production_cement
# - pvt_owned_house_under_const
# - residential_const_val
# - producer_price_index_concrete_brick

# %%
condf = df.copy()
condf = condf[["target","employees_construction","industrial_production_cement","pvt_owned_house_under_const","residential_const_val","producer_price_index_concrete_brick"]]

# %%
condf
# Out:
#              target  employees_construction  industrial_production_cement  \
# 2001-01-31  109.845                    6824                      139.6212
# 2001-02-28  110.499                    6841                      144.0119
# 2001-03-31  111.107                    6862                      147.6176
# 2001-04-30  111.650                    6844                      152.7136
# 2001-05-31  112.162                    6849                      149.7220
# ...             ...                     ...                           ...
# 2015-08-31  172.954                    6490                      114.2742
# 2015-09-30  173.848                    6508                      114.3883
# 2015-10-31  174.811                    6547                      113.1105
# 2015-11-30  175.755                    6598                      112.9790
# 2015-12-31  176.556                    6630                      119.8914
#
#             pvt_owned_house_under_const  residential_const_val  \
# 2001-01-31                        986.0                 348279
# 2001-02-28                        987.0                 353629
# 2001-03-31                       1001.0                 350029
# 2001-04-30                       1007.0                 361991
# 2001-05-31                       1015.0                 360534
# ...                                 ...                    ...
# 2015-08-31                        921.0                 438567
# 2015-09-30                        939.0                 447202
# 2015-10-31                        943.0                 448312
# 2015-11-30                        962.0                 447200
# 2015-12-31                        970.0                 453227
#
#             producer_price_index_concrete_brick
# 2001-01-31                                144.2
# 2001-02-28                                144.2
# 2001-03-31                                144.2
# 2001-04-30                                148.0
# 2001-05-31                                149.3
# ...                                         ...
# 2015-08-31                                208.4
# 2015-09-30                                208.4
# 2015-10-31                                208.4
# 2015-11-30                                208.4
# 2015-12-31                                208.4
#
# [180 rows x 6 columns]

# %%
condf["construction_cost"] = condf["residential_const_val"] / condf["pvt_owned_house_under_const"]

# %%
condf["employees_construction_cum"] = condf["employees_construction"].cumsum()

condf["residential_const_val_cum"] = condf["residential_const_val"].cumsum()

condf["pvt_owned_house_under_const_cum"] = condf["pvt_owned_house_under_const"].cumsum()

condf["industrial_production_cement_cum"] = condf["industrial_production_cement"].cumsum()


condf["construction_cost_cum"] = condf["construction_cost"].cumsum()

# %%
sns.heatmap(condf.corr(),annot=True)
# Out:
# <Axes: >

# %%
x = 12
condf["employees_construction_cum"] = condf["employees_construction"].rolling(window=x).sum()

condf["residential_const_val_cum"] = condf["residential_const_val"].rolling(window=x).sum()

condf["pvt_owned_house_under_const_cum"] = condf["pvt_owned_house_under_const"].rolling(window=x).sum()

condf["industrial_production_cement_cum"] = condf["industrial_production_cement"].rolling(window=x).sum()

condf["construction_cost_cum"] = condf["construction_cost"].rolling(window=x).sum()

# %%
sns.heatmap(condf.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - Construction variables are highly correlated with each other
# - The rolling sum of 12 months of residial construction value is the most correlated with the target

# %%
figure, axis = plt.subplots(1,1, figsize=(5,5))

sns.boxplot(condf['residential_const_val_cum'],)
# Out:
# <Axes: >

# %% [markdown]
# ## Housing industry
# - houses-for-sale-to-sold - Number of houses for sale vs number of houses got sold
# - home-ownership-rate
# - house_units_completed - Number of new house units completed in a given month
# - retail_sales_home_furnishing_stores - Sales of home furnishing stores

# %%
houdf = df.copy()
houdf = houdf[["target","houses-for-sale-to-sold","home-ownership-rate","house_units_completed","retail_sales_home_furnishing_stores"]]
houdf
# Out:
#              target  houses-for-sale-to-sold  home-ownership-rate  \
# 2001-01-31  109.845                      3.8                67.10
# 2001-02-28  110.499                      3.7                67.17
# 2001-03-31  111.107                      3.8                67.24
# 2001-04-30  111.650                      3.9                67.31
# 2001-05-31  112.162                      4.0                67.30
# ...             ...                      ...                  ...
# 2015-08-31  172.954                      5.0                64.29
# 2015-09-30  173.848                      5.9                64.30
# 2015-10-31  174.811                      5.6                64.17
# 2015-11-30  175.755                      5.5                64.04
# 2015-12-31  176.556                      5.1                63.91
#
#             house_units_completed  retail_sales_home_furnishing_stores
# 2001-01-31                 1456.0                                 7764
# 2001-02-28                 1536.0                                 7611
# 2001-03-31                 1470.0                                 7549
# 2001-04-30                 1574.0                                 7560
# 2001-05-31                 1497.0                                 7559
# ...                           ...                                  ...
# 2015-08-31                  974.0                                 9086
# 2015-09-30                 1040.0                                 9045
# 2015-10-31                  985.0                                 9162
# 2015-11-30                 1000.0                                 9152
# 2015-12-31                 1023.0                                 9361
#
# [180 rows x 5 columns]

# %%
sns.heatmap(houdf.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Distribution plots 
figure, axis = plt.subplots(2, 2, figsize=(25,10))

sns.histplot(houdf['houses-for-sale-to-sold'], ax=axis[0, 0])
axis[0, 0].set_title("houses-for-sale-to-sold")

sns.histplot(houdf['home-ownership-rate'], ax=axis[0, 1])
axis[0, 1].set_title("home-ownership-rate")



sns.histplot(houdf['house_units_completed'], ax=axis[1, 0])
axis[1, 0].set_title("house_units_completed")

sns.histplot(houdf['retail_sales_home_furnishing_stores'], ax=axis[1, 1])
axis[1, 1].set_title("retail_sales_home_furnishing_stores")
# Out:
# Text(0.5, 1.0, 'retail_sales_home_furnishing_stores')

# %%
# Box plots 
figure, axis = plt.subplots(2, 2, figsize=(25,10))

sns.boxplot(houdf['houses-for-sale-to-sold'], ax=axis[0, 0])
axis[0, 0].set_title("houses-for-sale-to-sold")

sns.boxplot(houdf['home-ownership-rate'], ax=axis[0, 1])
axis[0, 1].set_title("home-ownership-rate")



sns.boxplot(houdf['house_units_completed'], ax=axis[1, 0])
axis[1, 0].set_title("house_units_completed")

sns.boxplot(houdf['retail_sales_home_furnishing_stores'], ax=axis[1, 1])
axis[1, 1].set_title("retail_sales_home_furnishing_stores")
# Out:
# Text(0.5, 1.0, 'retail_sales_home_furnishing_stores')

# %%
plot_line(houdf,"target","houses-for-sale-to-sold")
# Out:
# [[1.        0.3594703]
#  [0.3594703 1.       ]]

# %%
x = 12
houdf["houses-for-sale-to-sold_cum"] = houdf["houses-for-sale-to-sold"].rolling(window=x).sum()

houdf["house_units_completed_cum"] = houdf["house_units_completed"].rolling(window=x).sum()

houdf["retail_sales_home_furnishing_stores_cum"] = houdf["retail_sales_home_furnishing_stores"].rolling(window=x).sum()

houdf["home-ownership-rate-cum"] = houdf["home-ownership-rate"].rolling(window=x).sum()

# %%
sns.heatmap(houdf.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Infrastructure and permits
# - nonresidential_const_val
# - permits

# %%
infdf = df.copy()
infdf = infdf[['target','permits','nonresidential_const_val']]

infdf
# Out:
#              target  permits  nonresidential_const_val
# 2001-01-31  109.845     1699                    278005
# 2001-02-28  110.499     1656                    270735
# 2001-03-31  111.107     1659                    280450
# 2001-04-30  111.650     1666                    278653
# 2001-05-31  112.162     1665                    281069
# ...             ...      ...                       ...
# 2015-08-31  172.954     1165                    425883
# 2015-09-30  173.848     1144                    425801
# 2015-10-31  174.811     1160                    419386
# 2015-11-30  175.755     1244                    420334
# 2015-12-31  176.556     1212                    414654
#
# [180 rows x 3 columns]

# %%
infdf["permits_cum"] = np.log((infdf["permits"].cumsum()))
infdf["nonresidential_const_val"] = np.log(infdf["nonresidential_const_val"].cumsum())

infdf["permits_cum"] = infdf["permits"].rolling(window=12).sum()
infdf["nonresidential_const_val"] = infdf["nonresidential_const_val"].rolling(window=12).sum()

# %%
sns.heatmap(infdf.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(infdf['permits'],)
# Out:
# <Axes: xlabel='permits', ylabel='Count'>

# %%
sns.histplot(infdf['nonresidential_const_val'],)
# Out:
# <Axes: xlabel='nonresidential_const_val', ylabel='Count'>
